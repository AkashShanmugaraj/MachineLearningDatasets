# %% [markdown]
# # Sarcasm Detector using TensorFlow

# %% [markdown]
# ### Importing Datasets

# %%
with open('Sarcasm_Headlines_Dataset_v2.json', 'r') as f:
    totaldata = f.readlines()

sentences = []
labels = []
urls = []

for item in totaldata:
    for news in eval(item):
        news = eval(item)
        sentences.append(news['headline'])
        labels.append(news['is_sarcastic'])
        urls.append(news['article_link'])

# %% [markdown]
# ### Defining some runtime variables

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 100
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000

# %% [markdown]
# ### Importing required Modules

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from datetime import datetime

# %% [markdown]
# ### Splitting Testing and Training set

# %%
training_sentences = sentences[0:10000]
testing_sentences = sentences[10000:]
training_labels = labels[0:10000]
testing_labels = labels[10000:]

# %% [markdown]
# ### Tokenizing and Padding datasets

# %%
tokenizer = Tokenizer(num_words=vocab_size,oov_token='oov')
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(training_sequences, padding='post', maxlen=max_length,truncating=trunc_type)
testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, padding='post', maxlen=max_length,truncating=trunc_type)
# Out:
# 2022-03-16 15:32:59.077226
# 2022-03-16 15:32:59.766261

# %% [markdown]
# ### Defining neural network

# %%
t1 = datetime.now()

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy', optimizer = 'adam',metrics=['accuracy'])
t2 = datetime.now()
print(t2-t1)
# Out:
# 2022-03-16 15:33:50.131527
# 2022-03-16 15:33:50.259525

# %% [markdown]
# ### Converting datalists as arrays

# %%
import numpy as np
training_padded = np.array(padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

# %% [markdown]
# ### Training the neural network

# %%
t1 = (datetime.now())
num_epochs = 50
history = model.fit(padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
t2 = (datetime.now())
print(t2-t1)
# Out:
# Epoch 1/50
# 313/313 - 7s - loss: 1.9417e-09 - accuracy: 1.0000 - val_loss: 1.8759 - val_accuracy: 0.7845 - 7s/epoch - 23ms/step
# Epoch 2/50
# 313/313 - 6s - loss: 1.9781e-09 - accuracy: 1.0000 - val_loss: 1.8631 - val_accuracy: 0.7864 - 6s/epoch - 21ms/step
# Epoch 3/50
# 313/313 - 6s - loss: 1.8993e-09 - accuracy: 1.0000 - val_loss: 1.8658 - val_accuracy: 0.7862 - 6s/epoch - 21ms/step
# Epoch 4/50
# 313/313 - 11s - loss: 1.9640e-09 - accuracy: 1.0000 - val_loss: 1.8649 - val_accuracy: 0.7863 - 11s/epoch - 37ms/step
# Epoch 5/50
# 313/313 - 7s - loss: 1.8857e-09 - accuracy: 1.0000 - val_loss: 1.8834 - val_accuracy: 0.7844 - 7s/epoch - 22ms/step
# Epoch 6/50
# 313/313 - 7s - loss: 1.9301e-09 - accuracy: 1.0000 - val_loss: 1.8627 - val_accuracy: 0.7871 - 7s/epoch - 21ms/step
# Epoch 7/50
# 313/313 - 6s - loss: 1.8212e-09 - accuracy: 1.0000 - val_loss: 1.8650 - val_accuracy: 0.7868 - 6s/epoch - 21ms/step
# Epoch 8/50
# 313/313 - 11s - loss: 1.8733e-09 - accuracy: 1.0000 - val_loss: 1.8796 - val_accuracy: 0.7847 - 11s/epoch - 37ms/step
# Epoch 9/50
# 313/313 - 6s - loss: 1.8590e-09 - accuracy: 1.0000 - val_loss: 1.8913 - val_accuracy: 0.7839 - 6s/epoch - 20ms/step
# Epoch 10/50
# 313/313 - 6s - loss: 1.8693e-09 - accuracy: 1.0000 - val_loss: 1.8848 - val_accuracy: 0.7842 - 6s/epoch - 21ms/step
# Epoch 11/50
# 313/313 - 7s - loss: 1.8293e-09 - accuracy: 1.0000 - val_loss: 1.8615 - val_accuracy: 0.7878 - 7s/epoch - 22ms/step
# Epoch 12/50
# 313/313 - 7s - loss: 1.8852e-09 - accuracy: 1.0000 - val_loss: 1.8627 - val_accuracy: 0.7875 - 7s/epoch - 21ms/step
# Epoch 13/50
# 313/313 - 11s - loss: 1.8937e-09 - accuracy: 1.0000 - val_loss: 1.9042 - val_accuracy: 0.7836 - 11s/epoch - 37ms/step
# Epoch 14/50
# 313/313 - 7s - loss: 1.9108e-09 - accuracy: 1.0000 - val_loss: 1.8977 - val_accuracy: 0.7838 - 7s/epoch - 21ms/step
# Epoch 15/50
# 313/313 - 11s - loss: 1.7947e-09 - accuracy: 1.0000 - val_loss: 1.9000 - val_accuracy: 0.7839 - 11s/epoch - 37ms/step
# Epoch 16/50
# 313/313 - 11s - loss: 1.8686e-09 - accuracy: 1.0000 - val_loss: 1.8910 - val_accuracy: 0.7844 - 11s/epoch - 37ms/step
# Epoch 17/50
# 313/313 - 11s - loss: 1.7514e-09 - accuracy: 1.0000 - val_loss: 1.8793 - val_accuracy: 0.7855 - 11s/epoch - 37ms/step
# Epoch 18/50
# 313/313 - 7s - loss: 1.7320e-09 - accuracy: 1.0000 - val_loss: 1.8882 - val_accuracy: 0.7845 - 7s/epoch - 21ms/step
# Epoch 19/50
# 313/313 - 12s - loss: 1.7798e-09 - accuracy: 1.0000 - val_loss: 1.8966 - val_accuracy: 0.7840 - 12s/epoch - 37ms/step
# Epoch 20/50
# 313/313 - 7s - loss: 1.7345e-09 - accuracy: 1.0000 - val_loss: 1.8833 - val_accuracy: 0.7846 - 7s/epoch - 21ms/step
# Epoch 21/50
# 313/313 - 11s - loss: 1.6917e-09 - accuracy: 1.0000 - val_loss: 1.8994 - val_accuracy: 0.7837 - 11s/epoch - 37ms/step
# Epoch 22/50
# 313/313 - 7s - loss: 1.7738e-09 - accuracy: 1.0000 - val_loss: 1.8980 - val_accuracy: 0.7840 - 7s/epoch - 21ms/step
# Epoch 23/50
# 313/313 - 7s - loss: 1.7438e-09 - accuracy: 1.0000 - val_loss: 1.9039 - val_accuracy: 0.7838 - 7s/epoch - 21ms/step
# Epoch 24/50
# 313/313 - 7s - loss: 1.7135e-09 - accuracy: 1.0000 - val_loss: 1.8790 - val_accuracy: 0.7858 - 7s/epoch - 21ms/step
# Epoch 25/50
# 313/313 - 7s - loss: 1.8379e-09 - accuracy: 1.0000 - val_loss: 1.8964 - val_accuracy: 0.7843 - 7s/epoch - 22ms/step
# Epoch 26/50
# 313/313 - 7s - loss: 1.6781e-09 - accuracy: 1.0000 - val_loss: 1.8783 - val_accuracy: 0.7863 - 7s/epoch - 21ms/step
# Epoch 27/50
# 313/313 - 7s - loss: 1.6670e-09 - accuracy: 1.0000 - val_loss: 1.8742 - val_accuracy: 0.7870 - 7s/epoch - 22ms/step
# Epoch 28/50
# 313/313 - 6s - loss: 1.8884e-09 - accuracy: 1.0000 - val_loss: 1.8835 - val_accuracy: 0.7852 - 6s/epoch - 20ms/step
# Epoch 29/50
# 313/313 - 7s - loss: 1.6610e-09 - accuracy: 1.0000 - val_loss: 1.9071 - val_accuracy: 0.7836 - 7s/epoch - 21ms/step
# Epoch 30/50
# 313/313 - 7s - loss: 1.7116e-09 - accuracy: 1.0000 - val_loss: 1.9056 - val_accuracy: 0.7838 - 7s/epoch - 22ms/step
# Epoch 31/50
# 313/313 - 11s - loss: 1.6929e-09 - accuracy: 1.0000 - val_loss: 1.9010 - val_accuracy: 0.7841 - 11s/epoch - 36ms/step
# Epoch 32/50
# 313/313 - 7s - loss: 1.6774e-09 - accuracy: 1.0000 - val_loss: 1.9030 - val_accuracy: 0.7841 - 7s/epoch - 21ms/step
# Epoch 33/50
# 313/313 - 6s - loss: 1.6513e-09 - accuracy: 1.0000 - val_loss: 1.8980 - val_accuracy: 0.7843 - 6s/epoch - 20ms/step
# Epoch 34/50
# 313/313 - 6s - loss: 1.6390e-09 - accuracy: 1.0000 - val_loss: 1.9155 - val_accuracy: 0.7835 - 6s/epoch - 20ms/step
# Epoch 35/50
# 313/313 - 11s - loss: 1.6926e-09 - accuracy: 1.0000 - val_loss: 1.8790 - val_accuracy: 0.7868 - 11s/epoch - 37ms/step
# Epoch 36/50
# 313/313 - 7s - loss: 1.6456e-09 - accuracy: 1.0000 - val_loss: 1.8940 - val_accuracy: 0.7846 - 7s/epoch - 21ms/step
# Epoch 37/50
# 313/313 - 11s - loss: 1.6635e-09 - accuracy: 1.0000 - val_loss: 1.8941 - val_accuracy: 0.7845 - 11s/epoch - 37ms/step
# Epoch 38/50
# 313/313 - 6s - loss: 1.7197e-09 - accuracy: 1.0000 - val_loss: 1.9013 - val_accuracy: 0.7845 - 6s/epoch - 20ms/step
# Epoch 39/50
# 313/313 - 6s - loss: 1.5939e-09 - accuracy: 1.0000 - val_loss: 1.8946 - val_accuracy: 0.7844 - 6s/epoch - 20ms/step
# Epoch 40/50
# 313/313 - 7s - loss: 1.6600e-09 - accuracy: 1.0000 - val_loss: 1.9489 - val_accuracy: 0.7818 - 7s/epoch - 21ms/step
# Epoch 41/50
# 313/313 - 6s - loss: 1.6519e-09 - accuracy: 1.0000 - val_loss: 1.8958 - val_accuracy: 0.7845 - 6s/epoch - 21ms/step
# Epoch 42/50
# 313/313 - 7s - loss: 1.6151e-09 - accuracy: 1.0000 - val_loss: 1.8947 - val_accuracy: 0.7845 - 7s/epoch - 22ms/step
# Epoch 43/50
# 313/313 - 7s - loss: 1.7011e-09 - accuracy: 1.0000 - val_loss: 1.8909 - val_accuracy: 0.7851 - 7s/epoch - 21ms/step
# Epoch 44/50
# 313/313 - 6s - loss: 1.5970e-09 - accuracy: 1.0000 - val_loss: 1.9061 - val_accuracy: 0.7842 - 6s/epoch - 20ms/step
# Epoch 45/50
# 313/313 - 6s - loss: 1.6403e-09 - accuracy: 1.0000 - val_loss: 1.9251 - val_accuracy: 0.7833 - 6s/epoch - 20ms/step
# Epoch 46/50
# 313/313 - 7s - loss: 1.6942e-09 - accuracy: 1.0000 - val_loss: 1.9101 - val_accuracy: 0.7840 - 7s/epoch - 21ms/step
# Epoch 47/50
# 313/313 - 6s - loss: 1.5931e-09 - accuracy: 1.0000 - val_loss: 1.8951 - val_accuracy: 0.7849 - 6s/epoch - 20ms/step
# Epoch 48/50
# 313/313 - 6s - loss: 1.5703e-09 - accuracy: 1.0000 - val_loss: 1.8836 - val_accuracy: 0.7870 - 6s/epoch - 20ms/step
# Epoch 49/50
# 313/313 - 7s - loss: 1.6249e-09 - accuracy: 1.0000 - val_loss: 1.8828 - val_accuracy: 0.7874 - 7s/epoch - 21ms/step
# Epoch 50/50
# 313/313 - 7s - loss: 1.5935e-09 - accuracy: 1.0000 - val_loss: 1.8993 - val_accuracy: 0.7844 - 7s/epoch - 21ms/step
# 2022-03-16 16:19:12.213213
# 2022-03-16 16:25:34.968000
# 0:06:22.754787

# %% [markdown]
# ### Testing the neural network

# %%
sentence = ["Elephant jumped out of the window", "The weather today is bright and sunny"]
sequences = tokenizer.texts_to_sequences(sentence)

# %%
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
