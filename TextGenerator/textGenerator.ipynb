# %% [markdown]
# # Text Generator using Tensorflow

# %% [markdown]
# ### Importing Dataset

# %%
f = open('tarunSpeech.txt')
corpus = f.read().split('\n')

# %% [markdown]
# ### Importing Required Modules

# %%
from datetime import datetime
t1 = datetime.now()
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
t2 = datetime.now()
print(t2-t1)
# Out:
# 0:00:12.309003

# %% [markdown]
# ### Tokenizing and Padding the Dataset

# %%
import numpy as np
tokenizer = Tokenizer(num_words=10000,oov_token='oov')
tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index)+1
print(total_words)
input_sequences = []

for line in corpus:
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        n_gram_sequence = token_list[:i+1]
        input_sequences.append(n_gram_sequence)
max_sequence_len = max([len(x) for x in input_sequences])

input_sequences = np.array(pad_sequences(input_sequences,maxlen=max_sequence_len,padding='pre'))
# Out:
# 146
# 0:00:00.009999

# %% [markdown]
# ### Splitting Test and Training Sequences

# %%
xs = input_sequences[:,:-1]
labels = input_sequences[:,-1]

ys = tf.keras.utils.to_categorical(labels,num_classes=total_words)

# %% [markdown]
# ### Defining a Neural Network model

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Embedding(total_words, 240, input_length=max_sequence_len-1))
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(150)))
model.add(tf.keras.layers.Dense(total_words, activation='softmax'))

# %% [markdown]
# ### Training the neural network

# %%
t1 = datetime.now()
model.compile(loss='categorical_crossentropy', optimizer = 'adam',metrics=['accuracy'])
history = model.fit(xs,ys, epochs = 50, verbose = 1)
t2 = datetime.now()
print(t2-t1)
# Out:
# 2022-03-16 17:24:07.029296
# Epoch 1/50
# 7/7 [==============================] - 9s 158ms/step - loss: 0.0218 - accuracy: 0.9860
# Epoch 2/50
# 7/7 [==============================] - 1s 150ms/step - loss: 0.0147 - accuracy: 0.9907
# Epoch 3/50
# 7/7 [==============================] - 1s 160ms/step - loss: 0.0162 - accuracy: 0.9860
# Epoch 4/50
# 7/7 [==============================] - 1s 138ms/step - loss: 0.0160 - accuracy: 0.9907
# Epoch 5/50
# 7/7 [==============================] - 1s 140ms/step - loss: 0.0201 - accuracy: 0.9860
# Epoch 6/50
# 7/7 [==============================] - 1s 138ms/step - loss: 0.0375 - accuracy: 0.9766
# Epoch 7/50
# 7/7 [==============================] - 1s 139ms/step - loss: 0.1474 - accuracy: 0.9439
# Epoch 8/50
# 7/7 [==============================] - 1s 158ms/step - loss: 0.0986 - accuracy: 0.9626
# Epoch 9/50
# 7/7 [==============================] - 1s 139ms/step - loss: 0.0422 - accuracy: 0.9766
# Epoch 10/50
# 7/7 [==============================] - 1s 149ms/step - loss: 0.0274 - accuracy: 0.9907
# Epoch 11/50
# 7/7 [==============================] - 1s 142ms/step - loss: 0.0298 - accuracy: 0.9907
# Epoch 12/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.0209 - accuracy: 0.9907
# Epoch 13/50
# 7/7 [==============================] - 1s 140ms/step - loss: 0.0187 - accuracy: 0.9907
# Epoch 14/50
# 7/7 [==============================] - 1s 130ms/step - loss: 0.0184 - accuracy: 0.9907
# Epoch 15/50
# 7/7 [==============================] - 1s 125ms/step - loss: 0.0174 - accuracy: 0.9907
# Epoch 16/50
# 7/7 [==============================] - 1s 120ms/step - loss: 0.0172 - accuracy: 0.9860
# Epoch 17/50
# 7/7 [==============================] - 1s 129ms/step - loss: 0.0168 - accuracy: 0.9860
# Epoch 18/50
# 7/7 [==============================] - 1s 124ms/step - loss: 0.0165 - accuracy: 0.9907
# Epoch 19/50
# 7/7 [==============================] - 1s 117ms/step - loss: 0.0159 - accuracy: 0.9907
# Epoch 20/50
# 7/7 [==============================] - 1s 143ms/step - loss: 0.0172 - accuracy: 0.9860
# Epoch 21/50
# 7/7 [==============================] - 1s 128ms/step - loss: 0.0158 - accuracy: 0.9907
# Epoch 22/50
# 7/7 [==============================] - 1s 134ms/step - loss: 0.0165 - accuracy: 0.9907
# Epoch 23/50
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0161 - accuracy: 0.9907
# Epoch 24/50
# 7/7 [==============================] - 1s 118ms/step - loss: 0.0158 - accuracy: 0.9860
# Epoch 25/50
# 7/7 [==============================] - 1s 126ms/step - loss: 0.0153 - accuracy: 0.9907
# Epoch 26/50
# 7/7 [==============================] - 1s 194ms/step - loss: 0.0168 - accuracy: 0.9860
# Epoch 27/50
# 7/7 [==============================] - 1s 155ms/step - loss: 0.0152 - accuracy: 0.9907
# Epoch 28/50
# 7/7 [==============================] - 1s 149ms/step - loss: 0.0154 - accuracy: 0.9860
# Epoch 29/50
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0152 - accuracy: 0.9907
# Epoch 30/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.0161 - accuracy: 0.9907
# Epoch 31/50
# 7/7 [==============================] - 1s 155ms/step - loss: 0.0160 - accuracy: 0.9907
# Epoch 32/50
# 7/7 [==============================] - 1s 156ms/step - loss: 0.0156 - accuracy: 0.9860
# Epoch 33/50
# 7/7 [==============================] - 1s 157ms/step - loss: 0.0148 - accuracy: 0.9907
# Epoch 34/50
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0152 - accuracy: 0.9907
# Epoch 35/50
# 7/7 [==============================] - 1s 123ms/step - loss: 0.0152 - accuracy: 0.9860
# Epoch 36/50
# 7/7 [==============================] - 1s 146ms/step - loss: 0.0157 - accuracy: 0.9813
# Epoch 37/50
# 7/7 [==============================] - 1s 136ms/step - loss: 0.0149 - accuracy: 0.9860
# Epoch 38/50
# 7/7 [==============================] - 1s 151ms/step - loss: 0.0153 - accuracy: 0.9813
# Epoch 39/50
# 7/7 [==============================] - 1s 130ms/step - loss: 0.0160 - accuracy: 0.9860
# Epoch 40/50
# 7/7 [==============================] - 1s 122ms/step - loss: 0.0150 - accuracy: 0.9907
# Epoch 41/50
# 7/7 [==============================] - 1s 124ms/step - loss: 0.0153 - accuracy: 0.9907
# Epoch 42/50
# 7/7 [==============================] - 1s 121ms/step - loss: 0.0152 - accuracy: 0.9860
# Epoch 43/50
# 7/7 [==============================] - 1s 163ms/step - loss: 0.0145 - accuracy: 0.9860
# Epoch 44/50
# 7/7 [==============================] - 1s 142ms/step - loss: 0.0154 - accuracy: 0.9860
# Epoch 45/50
# 7/7 [==============================] - 1s 149ms/step - loss: 0.0145 - accuracy: 0.9907
# Epoch 46/50
# 7/7 [==============================] - 1s 200ms/step - loss: 0.0149 - accuracy: 0.9860
# Epoch 47/50
# 7/7 [==============================] - 1s 140ms/step - loss: 0.0146 - accuracy: 0.9907
# Epoch 48/50
# 7/7 [==============================] - 2s 330ms/step - loss: 0.0156 - accuracy: 0.9860
# Epoch 49/50
# 7/7 [==============================] - 3s 372ms/step - loss: 0.0149 - accuracy: 0.9813
# Epoch 50/50
# 7/7 [==============================] - 2s 288ms/step - loss: 0.0149 - accuracy: 0.9907
# 2022-03-16 17:25:36.891882
# 0:01:29.862586

# %% [markdown]
# ### Generating Text from Neural Network

# %%
seed_text = 'Shit'
next_words = 10

for _ in range(next_words):
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    # predicted = model.predict_classes(token_list,verbose=0)
    predict_x=model.predict(token_list)
    classes_x=np.argmax(predict_x,axis=1)
    output_word = ''
    for word,index in tokenizer.word_index.items():
        if index == classes_x:
            output_word = word
            break
    seed_text += ' ' + output_word

# %%
print(seed_text)
f = open('out6.txt', 'w')
f.write(seed_text)
f.close()
# Out:
# Shit women who choose abortion donâ€™t have the financial resources to
